# %% [markdown]
# # Creating graphs from OBO ontologies
#
# The OBO (Open Biomedical Ontologies) flat file format is a way of representing knowledge that is both easily readable for humans and easily parsable for machines. Yet, imagining all the relations between different terms is very difficult, especially for larger ontologies. Also, the automated investigation of terms and their relations is quite difficult on a list basis.
# Therefore, a library that transforms the content of OBO files into the structure of a graph is useful since it allows for easy inspection of single terms and the connections they have to other terms as well as great visualization.
#
# Here, we introduce OBO.NET.Graph, a library that takes the OBO.NET parser and creates a graph from its terms list using the Graphoscope library.
#
# First, we reference the library:

# %%
#r "nuget: OBO.NET.Graph, 0.5.0-alpha.0"

open OBO.NET
open OBO.NET.Graph
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>OBO.NET.Graph, 0.5.0-alpha.0</span></li></ul></div></div>

# %% [markdown]
# Once this has been done, we parse the OBO file of our choice (here, we use the famous Gene Ontology that we download from the web):

# %%
#r "nuget: FSharp.Data"

let goContent = FSharp.Data.Http.RequestString(@"http://current.geneontology.org/ontology/go.obo").Split('\n')

let goOboOntology = OboOntology.fromLines false goContent
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>fsharp.data, 6.2.0</span></li></ul></div></div>

# %% [markdown]
# Now that we have the whole ontology as an `OboOntology` object, we want to transform it into an FGraph:

# %%
let goOntologyGraph = ontologyToFGraph true goOboOntology

# %% [markdown]
# Let's see what we can do with that...
#
# We want to investigate one of the terms in the ontology:
#
# ```yaml
# [Term]
# id: GO:0000001
# name: mitochondrion inheritance
# namespace: biological_process
# def: "The distribution of mitochondria, including the mitochondrial genome, into daughter cells after mitosis or meiosis, mediated by interactions between mitochondria and the cytoskeleton." [GOC:mcc, PMID:10873824, PMID:11389764]
# synonym: "mitochondrial inheritance" EXACT []
# is_a: GO:0048308 ! organelle inheritance
# is_a: GO:0048311 ! mitochondrion distribution
# ```
#
# There are 2 *is_a*s that this term points to. Let's get them from the ontology graph, using Graphoscope:

# %%
open Graphoscope

// getting the is_as as IDs first...
let isAs = FContext.successors goOntologyGraph["GO:0000001"]

// then mapping them to their respective OboTerm in the graph
let isATerms = isAs |> Seq.map (fun (id,relation) -> goOntologyGraph[id] |> fun (p,term,s) -> term)

isATerms
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { Id = &quot;GO:0048308&quot;
#   Name = &quot;organelle inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The partitioning of organelles between daughter cells at cell division.&quot; [GOC:jid]&quot;
#   Comment = &quot;&quot;
#   Subsets = [&quot;goslim_pir&quot;; &quot;goslim_yeast&quot;]
#   Synonyms = []
#   Xrefs = []
#   IsA = [&quot;GO:0006996&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0048311&quot;
#   Name = &quot;mitochondrion distribution&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;Any process that establishes the spatial arrangement of mitochondria between and within cells.&quot; [GOC:jid]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms =
#    [{ Text = &quot;&quot;distribution of mitochondria&quot;&quot;
#       Scope = Exact
#       TypeName = &quot;&quot;
#       DBXrefs = [] }; { Text = &quot;&quot;mitochondrial distribution&quot;&quot;
#                         Scope = Exact
#                         TypeName = &quot;&quot;
#                         DBXrefs = [] }; { Text = &quot;&quot;positioning of mitochondria&quot;&quot;
#                                           Scope = Related
#                                           TypeName = &quot;&quot;
#                                           DBXrefs = [] }]
#   Xrefs = []
#   IsA = [&quot;GO:0007005&quot;; &quot;GO:0051646&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; } ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@728[System.Tuple`2[System.String,System.String],OBO.NET.OboTerm]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@748-1[System.Tuple`2[System.String,System.String],OBO.NET.OboTerm]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0025+isATerms@7-3</code></span></summary><div><table><thead><tr></tr></thead><tbody></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>ie</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ (GO:0048308, is_a), (GO:0048311, is_a) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CheckClose</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>LastGenerated</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>s</td><td><table><thead><tr><th><i>key</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>GO:0048308</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0048311</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr></tbody></table></td></tr><tr><td>enum</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>pc</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>current</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>(GO:0048308, is_a)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Item1</td><td><div class="dni-plaintext"><pre>GO:0048308</pre></div></td></tr><tr><td>Item2</td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>(GO:0048311, is_a)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Item1</td><td><div class="dni-plaintext"><pre>GO:0048311</pre></div></td></tr><tr><td>Item2</td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ Id = &quot;GO:0048308&quot;\n  Name = &quot;organelle inheritance&quot;\n  IsAnonymous = false\n  AltIds = []\n  Definition =\n   &quot;&quot;The partitioning of organelles between daughter cells at cell division.&quot; [GOC:jid]&quot;\n  Comment = &quot;&quot;\n  Subsets = [&quot;goslim_pir&quot;; &quot;goslim_yeast&quot;]\n  Synonyms = []\n  Xrefs = []\n  IsA = [&quot;...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Id</td><td><div class="dni-plaintext"><pre>GO:0048308</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>organelle inheritance</pre></div></td></tr><tr><td>IsAnonymous</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>AltIds</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><d ...

# %% [markdown]
# What about terms that point to the first is_a term that we retrieved?

# %%
// again: first the IDs...
let pointingTermIds = FContext.predecessors goOntologyGraph[(Seq.head isATerms).Id]

// afterwards the OboTerms
let pointingTerms = pointingTermIds |> Seq.map (fun (id,relation) -> goOntologyGraph[id] |> fun (p,term,s) -> term)

pointingTerms
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { Id = &quot;GO:0000001&quot;
#   Name = &quot;mitochondrion inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The distribution of mitochondria, including the mitochondrial genome, into daughter cells after mitosis or meiosis, mediated by interactions between mitochondria and the cytoskeleton.&quot; [GOC:mcc, PMID:10873824, PMID:11389764]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms = [{ Text = &quot;&quot;mitochondrial inheritance&quot;&quot;
#                 Scope = Exact
#                 TypeName = &quot;&quot;
#                 DBXrefs = [] }]
#   Xrefs = []
#   IsA = [&quot;GO:0048308&quot;; &quot;GO:0048311&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0000011&quot;
#   Name = &quot;vacuole inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The distribution of vacuoles into daughter cells after mitosis or meiosis, mediated by interactions between vacuoles and the cytoskeleton.&quot; [GOC:mcc, PMID:10873824, PMID:14616069]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms = []
#   Xrefs = []
#   IsA = [&quot;GO:0007033&quot;; &quot;GO:0048308&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = [&quot;RO:0002161 NCBITaxon:4896&quot;]
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0009665&quot;
#   Name = &quot;plastid inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The partitioning of plastids between daughter cells at cell division.&quot; [GOC:mah]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms = []
#   Xrefs = []
#   IsA = [&quot;GO:0009657&quot;; &quot;GO:0048308&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0045033&quot;
#   Name = &quot;peroxisome inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The acquisition of peroxisomes by daughter cells from the mother cell after replication. In Saccharomyces cerevisiae, the number of peroxisomes cells is fairly constant; a subset of the organelles are targeted and segregated to the bud in a highly ordered, vectorial process. Efficient segregation of peroxisomes from mother to bud is dependent on the actin cytoskeleton, and active movement of peroxisomes along actin filaments is driven by the class V myosin motor protein, Myo2p.&quot; [PMID:11733545]&quot;
#   Comment =
#    &quot;Note that &#39;vectorial&#39; is used in the definition in the mathematical and physical sense of pertaining to &#39;a quantity having direction as well as magnitude, especially as determining the position of one point in space relative to another.&quot;
#   Subsets = []
#   Synonyms = []
#   Xrefs = []
#   IsA = [&quot;GO:0007031&quot;; &quot;GO:0048308&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0048309&quot;
#   Name = &quot;endoplasmic reticulum inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The partitioning of endoplasmic reticulum between daughter cells at cell division.&quot; [GOC:jid]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms = [{ Text = &quot;&quot;ER inheritance&quot;&quot;
#                 Scope = Exact
#                 TypeName = &quot;&quot;
#                 DBXrefs = [] }]
#   Xrefs = []
#   IsA = [&quot;GO:0007029&quot;; &quot;GO:0048308&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = [&quot;RO:0002161 NCBITaxon:4896&quot;]
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; }, { Id = &quot;GO:0048313&quot;
#   Name = &quot;Golgi inheritance&quot;
#   IsAnonymous = false
#   AltIds = []
#   Definition =
#    &quot;&quot;The partitioning of Golgi apparatus between daughter cells at cell division.&quot; [GOC:jid, PMID:12851069]&quot;
#   Comment = &quot;&quot;
#   Subsets = []
#   Synonyms =
#    [{ Text = &quot;&quot;Golgi apparatus inheritance&quot;&quot;
#       Scope = Exact
#       TypeName = &quot;&quot;
#       DBXrefs = [] };
#     { Text = &quot;&quot;Golgi division&quot;&quot;
#       Scope = Exact
#       TypeName = &quot;&quot;
#       DBXrefs = [{ Name = &quot;GOC:ascb_2009&quot;
#                    Description = &quot;&quot;
#                    Modifiers = &quot;&quot; }; { Name = &quot;GOC:dph&quot;
#                                        Description = &quot;&quot;
#                                        Modifiers = &quot;&quot; }; { Name = &quot;GOC:tb&quot;
#                                                            Description = &quot;&quot;
#                                                            Modifiers = &quot;&quot; }] };
#     { Text = &quot;&quot;Golgi partitioning&quot;&quot;
#       Scope = Exact
#       TypeName = &quot;&quot;
#       DBXrefs = [] }]
#   Xrefs = []
#   IsA = [&quot;GO:0007030&quot;; &quot;GO:0048308&quot;]
#   IntersectionOf = []
#   UnionOf = []
#   DisjointFrom = []
#   Relationships = []
#   IsObsolete = false
#   Replacedby = []
#   Consider = []
#   PropertyValues = []
#   BuiltIn = false
#   CreatedBy = &quot;&quot;
#   CreationDate = &quot;&quot; } ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@728[System.Tuple`2[System.String,System.String],OBO.NET.OboTerm]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@748-1[System.Tuple`2[System.String,System.String],OBO.NET.OboTerm]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0033+pointingTerms@5</code></span></summary><div><table><thead><tr></tr></thead><tbody></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>ie</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ (GO:0000001, is_a), (GO:0000011, is_a), (GO:0009665, is_a), (GO:0045033, is_a), (GO:0048309, is_a), (GO:0048313, is_a) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CheckClose</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>LastGenerated</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>p</td><td><table><thead><tr><th><i>key</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>GO:0000001</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0000011</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0009665</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0045033</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0048309</pre></div></td><td><div class="dni-plaintext"><pre>is_a</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>GO:0048313</pre></div></td><td><div class="dni-pl

# %% [markdown]
# ## Visualization
#
# We've seen how to work with ontology graphs, but what about visualization?
#
# The Gene Ontology is pretty big, with over 47k terms. Let's use a smaller subset of it so that we keep the overview:

# %%
let goSlimContent = FSharp.Data.Http.RequestString(@"https://current.geneontology.org/ontology/subsets/goslim_agr.obo").Split('\n')

let goSlimOboOntology = OboOntology.fromLines false goSlimContent

let goSlimOntologyGraph = ontologyToFGraph true goSlimOboOntology

# %% [markdown]
# We start with just printing the relations between each term:

# %%
Visualization.printGraphTermNames goSlimOntologyGraph
# Out:
# DNA-binding transcription factor activity ---"has_part"---> DNA binding
# endosome ---"is_a"---> cytoplasmic vesicle
# cell differentiation ---"is_a"---> developmental process
# synapse ---"is_a"---> cell junction

# %% [markdown]
# And here's how to turn them into Cytoscape graphs:

# %%
#r "nuget: Cytoscape.NET.Interactive"

Visualization.toCyGraph Visualization.matchRelationColorDefault false goSlimOntologyGraph
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Cytoscape.NET.Interactive, 0.2.0</span></li></ul></div></div>
# Loading extensions from `C:\Users\revil\.nuget\packages\cytoscape.net.interactive\0.2.0\interactive-extensions\dotnet\Cytoscape.NET.Interactive.dll`
# <div id="e4fb0b8b2aa" style="width:600px; height:600px"><!-- Cytoscape graph will be drawn inside this DIV --></div><script type="text/javascript">
#     var fsharpCytoscapeRequire = requirejs.config({context:'cytoscape-net',paths:{cytoscape:'https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.24.0/cytoscape.min'}}) || require;
#
#     fsharpCytoscapeRequire(['cytoscape'], function(cytoscape) {
#         var graphdata = {"container":document.getElementById('e4fb0b8b2aa'),"elements":[{"data":{"id":"GO:0003700","label":"DNA-binding transcription factor activity"}},{"data":{"id":"GO:0003677","label":"DNA binding"}},{"data":{"id":"GO:0003700_GO:0003677","source":"GO:0003700","target":"GO:0003677","label":"has_part","color":"black"}},{"data":{"id":"GO:0005768","label":"endosome"}},{"data":{"id":"GO:0031410","label":"cytoplasmic vesicle"}},{"data":{"id":"GO:0005768_GO:0031410","source":"GO:0005768","target":"GO:0031410","label":"is_a","color":"orange"}},{"data":{"id":"GO:0030154","label":"cell differentiation"}},{"data":{"id":"GO:0032502","label":"developmental process"}},{"data":{"id":"GO:0030154_GO:0032502","source":"GO:0030154","target":"GO:0032502","label":"is_a","color":"orange"}},{"data":{"id":"GO:0045202","label":"synapse"}},{"data":{"id":"GO:0030054","label":"cell junction"}},{"data":{"id":"GO:0045202_GO:0030054","source":"GO:0045202","target":"GO:0030054","label":"is_a","color":"orange"}}],"style":[{"selector":"node","style":{"content":"data(label)","color":"#A00975"}},{"selector":"edge","style":{"line-color":"data(color)"}}],"layout":{"name":"random"}}
#         var cy = cytoscape( graphdata );
#         cy.userZoomingEnabled( false );
#     });
#     </script>

# %% [markdown]
# We are using `matchRelationColorDefault` here that provides some basic coloring for the most common OboTerm relation types, but we can also create our own function for our needs:

# %%
open Cytoscape.NET

let matchRelationColorSpecific relation =
    match relation with
    | "is_a" -> CyParam.color "blue"
    | "has_part" -> CyParam.color "green"
    | _ -> CyParam.color "white"

Visualization.toCyGraph matchRelationColorSpecific false goSlimOntologyGraph
# Out:
# <div id="efcefff80d5" style="width:600px; height:600px"><!-- Cytoscape graph will be drawn inside this DIV --></div><script type="text/javascript">
#     var fsharpCytoscapeRequire = requirejs.config({context:'cytoscape-net',paths:{cytoscape:'https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.24.0/cytoscape.min'}}) || require;
#
#     fsharpCytoscapeRequire(['cytoscape'], function(cytoscape) {
#         var graphdata = {"container":document.getElementById('efcefff80d5'),"elements":[{"data":{"id":"GO:0003700","label":"DNA-binding transcription factor activity"}},{"data":{"id":"GO:0003677","label":"DNA binding"}},{"data":{"id":"GO:0003700_GO:0003677","source":"GO:0003700","target":"GO:0003677","label":"has_part","color":"green"}},{"data":{"id":"GO:0005768","label":"endosome"}},{"data":{"id":"GO:0031410","label":"cytoplasmic vesicle"}},{"data":{"id":"GO:0005768_GO:0031410","source":"GO:0005768","target":"GO:0031410","label":"is_a","color":"blue"}},{"data":{"id":"GO:0030154","label":"cell differentiation"}},{"data":{"id":"GO:0032502","label":"developmental process"}},{"data":{"id":"GO:0030154_GO:0032502","source":"GO:0030154","target":"GO:0032502","label":"is_a","color":"blue"}},{"data":{"id":"GO:0045202","label":"synapse"}},{"data":{"id":"GO:0030054","label":"cell junction"}},{"data":{"id":"GO:0045202_GO:0030054","source":"GO:0045202","target":"GO:0030054","label":"is_a","color":"blue"}}],"style":[{"selector":"node","style":{"content":"data(label)","color":"#A00975"}},{"selector":"edge","style":{"line-color":"data(color)"}}],"layout":{"name":"random"}}
#         var cy = cytoscape( graphdata );
#         cy.userZoomingEnabled( false );
#     });
#     </script>

# %% [markdown]
# Finally, the `toCyGraph` function also allows for incorporating single nodes without edges:

# %%
Visualization.toCyGraph matchRelationColorSpecific true goSlimOntologyGraph
# Out:
# <div id="e65410ed061" style="width:600px; height:600px"><!-- Cytoscape graph will be drawn inside this DIV --></div><script type="text/javascript">
#     var fsharpCytoscapeRequire = requirejs.config({context:'cytoscape-net',paths:{cytoscape:'https://cdnjs.cloudflare.com/ajax/libs/cytoscape/3.24.0/cytoscape.min'}}) || require;
#
#     fsharpCytoscapeRequire(['cytoscape'], function(cytoscape) {
#         var graphdata = {"container":document.getElementById('e65410ed061'),"elements":[{"data":{"id":"GO:0003700","label":"DNA-binding transcription factor activity"}},{"data":{"id":"GO:0003677","label":"DNA binding"}},{"data":{"id":"GO:0003700_GO:0003677","source":"GO:0003700","target":"GO:0003677","label":"has_part","color":"green"}},{"data":{"id":"GO:0005768","label":"endosome"}},{"data":{"id":"GO:0031410","label":"cytoplasmic vesicle"}},{"data":{"id":"GO:0005768_GO:0031410","source":"GO:0005768","target":"GO:0031410","label":"is_a","color":"blue"}},{"data":{"id":"GO:0030154","label":"cell differentiation"}},{"data":{"id":"GO:0032502","label":"developmental process"}},{"data":{"id":"GO:0030154_GO:0032502","source":"GO:0030154","target":"GO:0032502","label":"is_a","color":"blue"}},{"data":{"id":"GO:0045202","label":"synapse"}},{"data":{"id":"GO:0030054","label":"cell junction"}},{"data":{"id":"GO:0045202_GO:0030054","source":"GO:0045202","target":"GO:0030054","label":"is_a","color":"blue"}},{"data":{"id":"GO:0000003","label":"reproduction"}},{"data":{"id":"GO:0002376","label":"immune system process"}},{"data":{"id":"GO:0003677","label":"DNA binding"}},{"data":{"id":"GO:0003700","label":"DNA-binding transcription factor activity"}},{"data":{"id":"GO:0003723","label":"RNA binding"}},{"data":{"id":"GO:0003824","label":"catalytic activity"}},{"data":{"id":"GO:0005102","label":"signaling receptor binding"}},{"data":{"id":"GO:0005198","label":"structural molecule activity"}},{"data":{"id":"GO:0005215","label":"transporter activity"}},{"data":{"id":"GO:0005576","label":"extracellular region"}},{"data":{"id":"GO:0005634","label":"nucleus"}},{"data":{"id":"GO:0005694","label":"chromosome"}},{"data":{"id":"GO:0005739","label":"mitochondrion"}},{"data":{"id":"GO:0005768","label":"endosome"}},{"data":{"id":"GO:0005773","label":"vacuole"}},{"data":{"id":"GO:0005783","label":"endoplasmic reticulum"}},{"data":{"id":"GO:0005794","label":"Golgi apparatus"}},{"data":{"id":"GO:0005829","label":"cytosol"}},{"data":{"id":"GO:0005856","label":"cytoskeleton"}},{"data":{"id":"GO:0005886","label":"plasma membrane"}},{"data":{"id":"GO:0005975","label":"carbohydrate metabolic process"}},{"data":{"id":"GO:0006259","label":"DNA metabolic process"}},{"data":{"id":"GO:0006629","label":"lipid metabolic process"}},{"data":{"id":"GO:0007049","label":"cell cycle"}},{"data":{"id":"GO:0007610","label":"behavior"}},{"data":{"id":"GO:0008092","label":"cytoskeletal protein binding"}},{"data":{"id":"GO:0008134","label":"transcription factor binding"}},{"data":{"id":"GO:0008283","label":"cell population proliferation"}},{"data":{"id":"GO:0008289","label":"lipid binding"}},{"data":{"id":"GO:0009056","label":"catabolic process"}},{"data":{"id":"GO:0012501","label":"programmed cell death"}},{"data":{"id":"GO:0016043","label":"cellular component organization"}},{"data":{"id":"GO:0016070","label":"RNA metabolic process"}},{"data":{"id":"GO:0019538","label":"protein metabolic process"}},{"data":{"id":"GO:0023052","label":"signaling"}},{"data":{"id":"GO:0030054","label":"cell junction"}},{"data":{"id":"GO:0030154","label":"cell differentiation"}},{"data":{"id":"GO:0030234","label":"enzyme regulator activity"}},{"data":{"id":"GO:0030246","label":"carbohydrate binding"}},{"data":{"id":"GO:0031410","label":"cytoplasmic vesicle"}},{"data":{"id":"GO:0032502","label":"developmental process"}},{"data":{"id":"GO:0032991","label":"protein-containing complex"}},{"data":{"id":"GO:0036094","label":"small molecule binding"}},{"data":{"id":"GO:0038023","label":"signaling receptor activity"}},{"data":{"id":"GO:0042592","label":"homeostatic process"}},{"data":{"id":"GO:0042995","label":"cell projection"}},{"data":{"id":"GO:0045202","label":"synapse"}},{"data":{"id":"GO:0046872","label":"metal ion binding"}},{"data":{"id":"GO:0050877","label":"nervous system process"}},{"data":{"id":"GO:0050896","label":"response to stimulus"}},{"data":{"id":"GO:0051234","label":"establishment of localiza ...
#         var cy = cytoscape( graphdata );
#         cy.userZoomingEnabled( false );
#     });
#     </script>
